# %%
import sys
import importlib
from pathlib import Path

Path("introductory_exercise_suite_02").mkdir(parents=True, exist_ok=True)

PROJECT_ROOT = Path.cwd() / "introductory_exercise_suite_02"
sys.path.append(str(PROJECT_ROOT))

# %% [markdown]
# <h4>1. Use some mathematical functions to display any algebraic formula on the screen.</h4>

# %%
import math_functions_1

importlib.reload(math_functions_1).main()
# Out:
# Eq(mean, x1/3 + x2/3 + x3/3)

# %% [markdown]
# <h4>2. Use some mathematical functions to display any trigonometric formula on the screen.</h4>

# %%
import math_functions_2

importlib.reload(math_functions_2).main()
# Out:
# Eq(sinc(x), sin(x)/x)
