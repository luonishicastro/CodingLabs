# %% [markdown]
# **<h1>General Purpose Introductory List</h1>**

# %%
# %pwd
# Out:
# '/content'

# %%
import sys
import importlib
from pathlib import Path


PROJECT_ROOT = Path.cwd() / "introductory_exercise_suite_01"
sys.path.append(str(PROJECT_ROOT))

# %%
PROJECT_ROOT
# Out:
# PosixPath('/content/introductory_exercise_suite_01')
