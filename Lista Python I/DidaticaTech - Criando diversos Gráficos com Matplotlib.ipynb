# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.arange(-1000, 1000, 1)
y = x**2
plt.plot(x, y)
plt.show()

# %%
y1 = x**2
y2 = x**3
y3 = -x**2
y4 = -x**3
plt.subplot(2,2,1)
plt.plot(x, y1)
plt.subplot(2,2,2)
plt.plot(x, y2)
plt.subplot(2,2,3)
plt.plot(x, y3)
plt.subplot(2,2,4)
plt.plot(x, y4)
plt.show()

# %%
y1 = x**2
y2 = x**3
y3 = -x**2
y4 = -x**3

figura = plt.figure(figsize=(10,10))

figura.add_subplot(2,2,1)
plt.plot(x, y1)
figura.add_subplot(1,2,2)
plt.plot(x, y2)
figura.add_subplot(2,2,3)
plt.plot(x, y3)
plt.show()

# %%
from skimage.io import imread
#imagem = imread('\databases-python\imagem\BlackPower.jpg')
imagem = imread('C:/imagem1.jpg')
plt.imshow(imagem)
plt.show()

# %%
endereco = 'C:/'
imagens = []
for i in range(9):
    imagem = imread(endereco+'imagem'+str(i+1)+'.jpg')
    imagens.append(imagem)

# %%
figura = plt.figure(figsize=(15,8))
for i in range(9):
    figura.add_subplot(3,3,i+1)
    plt.imshow(imagens(i))
plt.show()
