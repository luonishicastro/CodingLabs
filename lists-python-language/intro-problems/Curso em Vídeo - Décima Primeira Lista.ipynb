# %% [markdown]
# Exercício 1 - Faça um programa que tenha uma função chamada ficha(), que receba dois parâmetros opcionais: o nome de um jogador e quantos gols ele marcou. O programa deverá ser capaz de mostrar a ficha do jogador, mesmo que algum dado não tenha sido informado corretamente.

# %%
def ficha(nome='<desconhecido>', gols=0):
    print(f'O jogador {nome} fez {gols} gol(s) no campeonato.')

print(25 * '-')
n = str(input('Nome do jogador: '))
g = str(input('Número de Gols: '))

if g.isnumeric():
    g = int(g)
else:
    g = 0
    
if n.strip() == '':
    ficha(gols=g)
else:
    ficha(n, g)
# Out:
# -------------------------
# Nome do jogador:
# Número de Gols:
# O jogador <desconhecido> fez 0 gol(s) no campeonato.

# %% [markdown]
# Exercício 2 - Crie um programa que tenha a função leiaInt(), que vai funcionar de forma semelhante à função input() do Python, só que fazendo a validação para aceitar apenas um valor numérico.

# %%
def leiaInt(msg):
    erro = True
    while erro:
        n = str(input(msg))
        if str(n).isnumeric() == True:
            return n
            break
        else:
            print('\033[0;31mERRO! Digite um número inteiro válido.\033[m')

n = leiaInt('Digite um número: ')
print(f'Você acabou de digitar o número {n}')
# Out:
# Digite um número: abaduba
# ERRO! Digite um número inteiro válido.
# Digite um número: um
# ERRO! Digite um número inteiro válido.
# Digite um número: 5
# Você acabou de digitar o número 5

# %% [markdown]
# Exercício 3 - Faça um programa que tenha uma função notas() que pode receber várias notas de alunos e var retornar um dicionário com as seguintes informações:
# <br>-Quantidade de notas
# <br>-A maior nota
# <br>-A menor nota
# <br>-A média da turma
# <br>-A situação (opcional)
# <br>Adicione também as docstrings.

# %%
def notas(*notas, sit=False):
    '''
    -> Função para analisar notas e situação de vários alunos.
    :param notas: uma oumais notas dos alunos (aceita várias)
    :param sit: valor opcional, indicando se deve ou não adicionar a situação
    :return: dicionário com várias informações sobre a situação da turma.
    '''
    
    boletim = dict()
    boletim['total'] = len(list(notas))
    boletim['maior'] = max(list(notas))
    boletim['menor'] = min(list(notas))
    boletim['média'] = sum(list(notas))/len(list(notas))
    
    if sit:
        if sum(list(notas))/len(list(notas)) <= 5:
            boletim['situação'] = 'RUIM'
        elif sum(list(notas))/len(list(notas)) > 5 and sum(list(notas))/len(list(notas)) <= 7:
            boletim['situação'] = 'MÉDIO'
        else:
            boletim['situação'] = 'BOM'
    
    return boletim
    
print('\n',20*'--')

# Programa principal
resp = notas(5.5, 2.5, 10, 6.5, sit=True)
print(resp)
help(notas)
# Out:
#  ----------------------------------------
# {'total': 4, 'maior': 10, 'menor': 2.5, 'média': 6.125, 'situação': 'MÉDIO'}
# Help on function notas in module __main__:
#
# notas(*notas, sit=False)
#     -> Função para analisar notas e situação de vários alunos.
#     :param notas: uma oumais notas dos alunos (aceita várias)
#     :param sit: valor opcional, indicando se deve ou não adicionar a situação
#     :return: dicionário com várias informações sobre a situação da turma.

# %% [markdown]
# Exercício 3 - Faça um mini-sistema que utilize o Interactive Help do Python. O usuário vai digitar o comando e o manual vai aparecer. Quando o usuário digitar a palavra 'FIM', o programa se encerrará.

# %%
def ajuda(funcao):
    return help(funcao)

print(25*'~')
print('SISTEMA DE AJUDA PyHELP')
print(25*'~')

while True:
    msg = str(input('Função ou Biblioteca> '))
    
    if msg != 'fim':
        print(25*'~')
        print(f'Acessando manual do comando {msg}')
        print(25*'~')
        
        ajuda(msg)
    else:
        break
        
print(15*'~')
print('ATÉ LOGO!')
print(15*'~')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# SISTEMA DE AJUDA PyHELP
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# Função ou Biblioteca> abaduba
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# Acessando manual do comando abaduba
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# No Python documentation found for 'abaduba'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# Função ou Biblioteca> random
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# Acessando manual do comando random
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# DESCRIPTION
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
#                triangular
# ...

# %% [markdown]
# Exercício 4 - Crie um módulo chamado moeda.py que tenha as funções incorporadas aumentar(), diminuir(), dobro() e metade(). Faça também um programa que importe esse módulo e use algumas dessas funções.

# %%
dir(moeda)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'aumentar',
#  'diminuir',
#  'dobro',
#  'metade']

# %%
import moeda

preco = float(input('Digite o preço: R$'))
print('A metade de R${:.2f} é R${:.2f}'.format(preco, moeda.metade(preco)))
print('O dobro de R${:.2f} é R${:.2f}'.format(preco, moeda.dobro(preco)))
print('Aumentando 10%, temos R${:.2f}'.format(moeda.aumentar(preco)))
print('Diminuindo 10%, temos R${:.2f}'.format(moeda.diminuir(preco)))
# Out:
# Digite o preço: R$234.34
# A metade de R$234.34 é R$117.17
# O dobro de R$234.34 é R$468.68
# Aumentando 10%, temos R$257.77
# Diminuindo 10%, temos R$210.91

# %% [markdown]
# Exercício 5 - Adapte o código do desafio 107, criando uma função adicional chamada moeda() que consiga mostrar os valores como um valor monetário formatado.

# %%
import moeda

preco = float(input('Digite o preço: R$'))
print('A metade de R${} é R${}'.format(str(preco).replace('.',','), moeda.moeda(moeda.metade(preco))))
print('O dobro de R${} é R${}'.format(str(preco).replace('.',','), moeda.moeda(moeda.dobro(preco))))
print('Aumentando 10%, temos R${}'.format(moeda.moeda(moeda.aumentar(preco))))
print('Diminuindo 10%, temos R${}'.format(moeda.moeda(moeda.diminuir(preco))))
# Out:
# Digite o preço: R$234.23
# A metade de R$234,23 é R$117,11
# O dobro de R$234,23 é R$468,46
# Aumentando 10%, temos R$257,65
# Diminuindo 10%, temos R$210,81

# %% [markdown]
# Exercício 6 - Modifique as funções que foram criadas no desafio 107 para que elas aceitem um parâmetro a mais, informando se o valor retornado por elas vai ser ou não formatado pela função moeda(), desenvolvida no desafio 108.

# %%
import moeda

preco = float(input('Digite o preço: R$'))
print('A metade de R${} é R${}'.format(moeda.moeda(preco), moeda.metade(preco, True)))
print('O dobro de R${} é R${}'.format(moeda.moeda(preco), moeda.dobro(preco, True)))
print('Aumentando 10%, temos R${}'.format(moeda.aumentar(preco, True)))
print('Diminuindo 10%, temos R${}'.format(moeda.diminuir(preco, True)))
# Out:
# Digite o preço: R$234.34
# A metade de R$234,34 é R$117,17
# O dobro de R$234,34 é R$468,68
# Aumentando 10%, temos R$257,77
# Diminuindo 10%, temos R$210,91

# %% [markdown]
# Exercício 7 - Crie um pacote chamado utilidadesCev que tenha dois módulos internos chamados moeda e dado. Transfira todas as funções utilizadas nos desafios 107, 108 e 109 para o primeiro pacote e mantenha tudo funcionando.

# %%
from utilidadesCev import moeda
from utilidadesCev import dado

preco = float(input('Digite o preço: R$'))
print('A metade de R${} é R${}'.format(moeda.moeda(preco), moeda.metade(preco, True)))
print('O dobro de R${} é R${}'.format(moeda.moeda(preco), moeda.dobro(preco, True)))
print('Aumentando 10%, temos R${}'.format(moeda.aumentar(preco, True)))
print('Diminuindo 10%, temos R${}'.format(moeda.diminuir(preco, True)))
print(dado.resumo())
# Out:
# Digite o preço: R$234.34
# A metade de R$234,34 é R$117,17
# O dobro de R$234,34 é R$468,68
# Aumentando 10%, temos R$257,77
# Diminuindo 10%, temos R$210,91
# RESUMO DO VALOR.

# %% [markdown]
# Exercício 8 - Dentro do pacote utilidadesCev que criamos no desafio 111, temos um módulo chamado dado. Crie uma função chamada leiaDinheiro() que seja capaz de funcionar como uma função input(), mas com uma validação de dados para aceitar apenas valores que sejam monetários.

# %%
from utilidadesCev import moeda
from utilidadesCev import dado

preco = dado.leiaDinheiro('Digite o preço: R$')
print('A metade de R${} é R${}'.format(moeda.moeda(preco), moeda.metade(preco, True)))
print('O dobro de R${} é R${}'.format(moeda.moeda(preco), moeda.dobro(preco, True)))
print('Aumentando 10%, temos R${}'.format(moeda.aumentar(preco, True)))
print('Diminuindo 10%, temos R${}'.format(moeda.diminuir(preco, True)))
print(dado.resumo())
# Out:
# Digite o preço: R$123.34
# A metade de R$123,34 é R$61,67
# O dobro de R$123,34 é R$246,68
# Aumentando 10%, temos R$135,67
# Diminuindo 10%, temos R$111,01
# RESUMO DO VALOR.

# %% [markdown]
# Exercício 9 - Crie um código em Python que teste se o site Pudim está acessível pelo computador usado.

# %%
import urllib
import urllib.request

try:
    site = urllib.request.urlopen('http://www.pudim.com.br')
except urllib.error.URLError:
    print('O site pudim não está disponível no momento.')
else:
    print('Consegui acessar o site Pudim com sucesso.')
    print(site.read())
# Out:
# O site pudim não está disponível no momento.

# %% [markdown]
# Exercício 10 - Crie um pequeno sistema modularizado que permite cadastrar pessoas pelo seu nome e idade em um arquivo de texto simples. O sistema só vai ter 2 opções: cadastrar uma nova pessoa e listar todas as pessoas cadastradas.

# %%
from lib import interface
from lib import arquivo
from lib import leiaNum
from time import sleep

arq = 'cursoemvideo.txt'

if not arquivo.arquivoExiste(arq):
    arquivo.criarArquivo(arq)

while True:
    resposta = interface.menu(['Ver pessoas cadastradas', 'Cadastrar nova Pessoa', 'Sair do Sistema'])
    if resposta == 1:
        # Opção de listar o conteúdo de um arquivo!
        arquivo.lerArquivo(arq)
    elif resposta == 2:
        # Opção para cadastrar uma nova pessoa.
        interface.cabecalho('NOVO CADASTRO')
        nome = str(input('Nome: '))
        idade = leiaNum.leiaInt('Idade: ')
        arquivo.cadastrar(arq, nome, idade)
    elif resposta == 3:
        interface.cabecalho('Saindo do sistema... Até logo!')
        break
    else:
        print('\033[31mERRO! Digite uma opção válida!\033[m')
    sleep(1)
# Out:
# ------------------------------------------
#               MENU PRINCIPAL
# ------------------------------------------
# 1 -  Ver pessoas cadastradas
# 2 -  Cadastrar nova Pessoa
# 3 -  Sair do Sistema
# ------------------------------------------
# Sua Opção: 1
# ------------------------------------------
#            PESSOAS CADASTRADAS
# ------------------------------------------
# José                           35 anos
# Lucas                          26 anos
# ------------------------------------------
#               MENU PRINCIPAL
# ------------------------------------------
# 1 -  Ver pessoas cadastradas
# 2 -  Cadastrar nova Pessoa
# 3 -  Sair do Sistema
# ------------------------------------------
# Sua Opção: 2
# ------------------------------------------
#               NOVO CADASTRO
# ------------------------------------------
# Nome: Maria
# Idade: 85
# Novo registro de Maria adicionado.
# ------------------------------------------
#               MENU PRINCIPAL
# ...
