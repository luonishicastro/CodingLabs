# %% [markdown]
# Exercício 1 - Importações e Configuração

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs , init_notebook_mode, plot, iplot

print(__version__)
# Out:
# 3.10.0

# %%
import cufflinks as cf

# %%
#Para notebooks
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Offline Use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Exercício 2 - Dados forjados

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -1.367726 -0.632746 -0.201958  1.562579
# 1  0.580367  0.130139 -0.465888 -0.813370
# 2 -0.727102 -3.265475 -0.499850 -0.173054
# 3 -0.621732 -1.196417  1.180340 -0.903632
# 4 -0.648274 -0.031480  1.411206  0.288244

# %%
df2 = pd.DataFrame({'Categoria': ['A', 'B', 'C'], 'Valores':[32, 43, 50]})

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -1.367726 -0.632746 -0.201958  1.562579
# 1  0.580367  0.130139 -0.465888 -0.813370
# 2 -0.727102 -3.265475 -0.499850 -0.173054
# 3 -0.621732 -1.196417  1.180340 -0.903632
# 4 -0.648274 -0.031480  1.411206  0.288244

# %% [markdown]
# Exercício 3 - Gráfico de Dispersão

# %%
df.iplot(kind='scatter', x='A', y='B', mode='markers', size=10)
# Out:
# <div>
#
#
#             <div id="a14b2302-347b-465a-abfe-d5f709efb3d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a14b2302-347b-465a-abfe-d5f709efb3d9")) {
#                     Plotly.newPlot(
#                         'a14b2302-347b-465a-abfe-d5f709efb3d9',
# ...

# %% [markdown]
# Exercício 4 - Plots de barra

# %%
df2.iplot(kind='bar', x='Categoria', y='Valores')
# Out:
# <div>
#
#
#             <div id="204a9b80-f828-4925-8168-7142754ef179" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("204a9b80-f828-4925-8168-7142754ef179")) {
#                     Plotly.newPlot(
#                         '204a9b80-f828-4925-8168-7142754ef179',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Valores", "orientation": "v", "text": "", "type": "bar", "uid": "51b76e5c-2aa2-4422-91f8-7ad474a509ce", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.count().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="9dac8d96-69c1-45c4-8de3-92734b3c2bd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9dac8d96-69c1-45c4-8de3-92734b3c2bd3")) {
#                     Plotly.newPlot(
#                         '9dac8d96-69c1-45c4-8de3-92734b3c2bd3',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "40f2113a-4ac3-4b40-8316-4a79559786d0", "x": ["A", "B", "C", "D"], "y": [100, 100, 100, 100]}],
# ...

# %% [markdown]
# Exercício 5 - Boxplots

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="5ac1dd4e-b8dd-43e5-8e30-643f26c12e20" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5ac1dd4e-b8dd-43e5-8e30-643f26c12e20")) {
#                     Plotly.newPlot(
#                         '5ac1dd4e-b8dd-43e5-8e30-643f26c12e20',
# ...

# %% [markdown]
# Exercício 6 - Superfícies 3D

# %%
df3 = pd.DataFrame({'x': [1, 2, 3, 4, 5], 'y': [10, 20, 30, 20, 10], 'z':[5, 4, 3, 2, 1]})
df3.iplot(kind='surface', colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="df02897b-efdf-456a-b56d-36d6dce0798e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("df02897b-efdf-456a-b56d-36d6dce0798e")) {
#                     Plotly.newPlot(
#                         'df02897b-efdf-456a-b56d-36d6dce0798e',
# ...

# %% [markdown]
# Exercício 7 - Gráfico de Spread

# %%
df[['A', 'B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="eb5cfcfa-51b8-4785-9d52-682c017b722d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("eb5cfcfa-51b8-4785-9d52-682c017b722d")) {
#                     Plotly.newPlot(
#                         'eb5cfcfa-51b8-4785-9d52-682c017b722d',
# ...

# %% [markdown]
# Exercício 8 - Histograma

# %%
df['A'].iplot(kind='hist', bins=25)
# Out:
# <div>
#
#
#             <div id="3b2cd4e4-efc7-497a-937c-ac68033cc19e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3b2cd4e4-efc7-497a-937c-ac68033cc19e")) {
#                     Plotly.newPlot(
#                         '3b2cd4e4-efc7-497a-937c-ac68033cc19e',
# ...

# %% [markdown]
# Exercício 9 - Gráfico de Bolha

# %%
df.iplot(kind='bubble', x='A', y='B', size='C')
# Out:
# <div>
#
#
#             <div id="c4ce7c65-abec-4721-bb24-38b68ff29470" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c4ce7c65-abec-4721-bb24-38b68ff29470")) {
#                     Plotly.newPlot(
#                         'c4ce7c65-abec-4721-bb24-38b68ff29470',
# ...

# %% [markdown]
# Exercício 10 - Gráfico de scatter_matrix()

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="875111ba-2cbb-43f1-8adc-1b42f3f7a11b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("875111ba-2cbb-43f1-8adc-1b42f3f7a11b")) {
#                     Plotly.newPlot(
#                         '875111ba-2cbb-43f1-8adc-1b42f3f7a11b',
# ...
